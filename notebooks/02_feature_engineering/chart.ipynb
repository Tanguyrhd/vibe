# %%
import matplotlib.pyplot as plt

# %%
X = ['XGBoost', 'Combined model', 'Bert', 'genAI']
y = [15, 17, 20, 27]

# %%
plt.barh(X, y, color='#A64527')
plt.xlabel('Accuracy score in %')
plt.title('Model Performance')
plt.show()
